# %% [markdown]
# <a href="https://colab.research.google.com/github/akilapv12/Quantum-Computing/blob/main/Python_Grade_9_AIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcom")
print("hi")
