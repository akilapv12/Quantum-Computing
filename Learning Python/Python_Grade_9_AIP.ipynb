# %% [markdown]
# <a href="https://colab.research.google.com/github/akilapv12/Quantum-Computing/blob/main/Learning%20Python/Python_Grade_9_AIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python AI Practicals - Grade 9

# %%
# print(details)

name = "Akil"
surname = "Adhiyaman"
school = "DPS Dubai"
section = "9B"
d_num = "D10919"
print("Full Name :", name, surname)
print("School :", school)
print("Class :", section)
print("D.Num. :", d_num)
# Out:
# Full Name : Akil Adhiyaman
# School : DPS Dubai
# Class : 9B
# D.Num. : D10919

# %%
# My Introduction

name = input("Enter your name : ")
surname = input("Enter your surname : ")
age = input("Enter your age : ")
school = input("Enter your school : ")
section = input("Enter your section : ")
hobby = input("Enter you hobby : ")
print(f"\nMy name is {name} {surname}. \nI am {age} years old. \nI study in {school} in {section}. \nMy hobyy is {hobby}.")
# Out:
# Enter your name : Akil
# Enter your surname : Adhiyaman
# Enter your age : 14
# Enter your school : DPS Dubai
# Enter your section : 9B
# Enter you hobby : Cycling
#
# My name is Akil Adhiyaman.
# I am 14 years old.
# I study in DPS Dubai in 9B.
# My hobyy is Cycling.
